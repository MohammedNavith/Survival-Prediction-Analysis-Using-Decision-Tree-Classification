# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('D:/data/Breast_Cancer.csv')
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
df.head()
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# ...

# %%
df.tail()
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 4019  Moderately differentiated     2  Regional           9        Positive
# 4020  Moderately differentiated     2  Regional          46        Positive
# 4021  Moderately differentiated     2  Regional          22        Positive
# 4022  Moderately differentiated     2  Regional          44        Positive
# 4023  Moderately differentiated     2  Regional          30        Positive
#
#      Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 4019            Positive                       1                      1
# ...

# %%
df.describe()
# Out:
#                Age   Tumor Size  Regional Node Examined  \
# count  4024.000000  4024.000000             4024.000000
# mean     53.972167    30.473658               14.357107
# std       8.963134    21.119696                8.099675
# min      30.000000     1.000000                1.000000
# 25%      47.000000    16.000000                9.000000
# 50%      54.000000    25.000000               14.000000
# 75%      61.000000    38.000000               19.000000
# max      69.000000   140.000000               61.000000
#
#        Reginol Node Positive  Survival Months
# count            4024.000000      4024.000000
# mean                4.158052        71.297962
# std                 5.109331        22.921430
# min                 1.000000         1.000000
# 25%                 1.000000        56.000000
# 50%                 2.000000        73.000000
# 75%                 5.000000        90.000000
# max                46.000000       107.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   T Stage                 4024 non-null   object
#  4   N Stage                 4024 non-null   object
#  5   6th Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %%
df.shape
# Out:
# (4024, 16)

# %%
df.isnull().sum()
# Out:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4019    False
# 4020    False
# 4021    False
# 4022    False
# 4023    False
# Length: 4024, dtype: bool

# %%
plt.figure(figsize = (16,9))
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status'],
#       dtype='object')

# %%
df['Race'].unique()
# Out:
# array(['White', 'Black', 'Other'], dtype=object)

# %%
df['Marital Status'].unique()
# Out:
# array(['Married', 'Divorced', 'Single ', 'Widowed', 'Separated'],
#       dtype=object)

# %%
df['differentiate'].unique()
# Out:
# array(['Poorly differentiated', 'Moderately differentiated',
#        'Well differentiated', 'Undifferentiated'], dtype=object)

# %%
df['Grade'].unique()
# Out:
# array(['3', '2', '1', ' anaplastic; Grade IV'], dtype=object)

# %%
df['Estrogen Status'].unique()
# Out:
# array(['Positive', 'Negative'], dtype=object)

# %% [markdown]
# 1.Age Distribution

# %%
plt.figure(figsize=(16,9))
sns.histplot(df['Age'], kde = True,bins=20, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 2.Tumor Size

# %%
plt.figure(figsize = (16,9))
sns.histplot(df['Tumor Size'], kde = True, bins = 20)
plt.title("Tumor Size")
plt.xlabel("Tumor Size")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 3.Survival Months

# %%
plt.figure(figsize = (16,9))
sns.histplot(df["Survival Months"], kde = True, bins = 20)
plt.xlabel("Survival Months")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 4.Status

# %%
plt.figure(figsize = (16,9))
sns.barplot(df["Status"])
plt.show()

# %% [markdown]
# 5.Survival Months Vs Tumor Size

# %%
plt.figure(figsize=(16, 9))
sns.scatterplot(data=df, x='Tumor Size', y='Survival Months', hue='Estrogen Status', palette='viridis')
plt.title('Survival Months vs Tumor Size')
plt.xlabel('Tumor Size (mm)')
plt.ylabel('Survival Months')
plt.legend(title="Hormone Status")
plt.show()

# %% [markdown]
# A dense cluster of points at smaller tumor sizes (around 0–50 mm) suggests that most individuals had smaller tumors.
# The survival months are widely distributed for both small and large tumor sizes.
# There doesn't appear to be a strong linear relationship between tumor size and survival months based on this scatter plot.

# %% [raw]
# 1.Positive Estrogen Status (ER-positive):
# The tumor cells have estrogen receptors, meaning they rely on estrogen to grow and multiply.
# Implications:
# Usually associated with slower-growing cancers.
# More likely to respond to hormone therapies like Tamoxifen or Aromatase Inhibitors, which block estrogen's effects.
# Often has a better prognosis compared to ER-negative cancers.
# 2. Negative Estrogen Status (ER-negative):
# The tumor cells do not have estrogen receptors, meaning they do not depend on estrogen for growth.
# Implications:
# These cancers tend to grow and spread faster than ER-positive cancers.
# Hormone therapy is generally ineffective; other treatments, like chemotherapy, are typically used.
# Prognosis can be poorer than ER-positive cancers, depending on other factors.

# %%
plt.figure(figsize = (16,9))
sns.barplot(data = df, x = df['Estrogen Status'], y = df['Survival Months'], palette = 'coolwarm')
plt.title("Survival Months Vs strogen Status")
plt.xlabel("Estrogen Status")
plt.ylabel("Survival Months")
plt.show()
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_13604\548221729.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = df, x = df['Estrogen Status'], y = df['Survival Months'], palette = 'coolwarm')

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='T Stage ', y='Survival Months', palette='Set3')
plt.title('T Stage vs Survival Months')
plt.xlabel('T Stage')
plt.ylabel('Survival Months')
plt.show()
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_13604\757377575.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='T Stage ', y='Survival Months', palette='Set3')

# %%
df.columns
# Out:
# Index(['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1 = df.copy()

# %%
object1 = LabelEncoder()

# %%
df1['T_Stage_1'] = object1.fit_transform(df1['T Stage '])
df1['Estrogen_Status_1'] = object1.fit_transform(df1['Estrogen Status'])
df1['Survival_Status_1'] = object1.fit_transform(df1['Status'])

# %%
df1.head()
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# ...

# %%
df1.columns
# Out:
# Index(['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status', 'T_Stage_1',
#        'Estrogen_Status_1', 'Survival_Status_1'],
#       dtype='object')

# %%
numerical_cols = ['Age', 'Tumor Size', 'Estrogen_Status_1', 'T_Stage_1', 'Survival Months']
correlation_matrix = df1[numerical_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', cbar=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Key Observations:
# Diagonal Values (Correlation = 1):
#
# These represent the correlation of a variable with itself, which is always 1.
# Tumor Size and T Stage:
#
# A strong positive correlation of 0.81 indicates that as the tumor size increases, the T stage tends to be higher. This makes sense clinically, as T stage often reflects tumor size.
# Estrogen Status and Survival Months:
#
# A weak positive correlation of 0.13 suggests that patients with positive estrogen status might survive slightly longer, but the relationship is not very strong.
# Tumor Size and Survival Months:
#
# A slight negative correlation of -0.09 indicates that larger tumors may be associated with shorter survival, but the effect is minimal.
# Age and Other Variables:
#
# Age shows very weak correlations with all variables, suggesting that age alone may not be a significant factor in determining these outcomes.
# T Stage and Survival Months:
#
# A weak negative correlation of -0.09 shows that higher T stages may slightly reduce survival months, though the relationship is not strong.

# %%
df1.Status.unique()
# Out:
# array(['Alive', 'Dead'], dtype=object)

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
x = df1[['Age','T_Stage_1','Estrogen_Status_1','Tumor Size','Regional Node Examined','Reginol Node Positive']]
y = df1['Survival_Status_1']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 10)

# %%
dtf = DecisionTreeClassifier()

# %%
dtf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtf.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 0.76
# Confusion Matrix:
# [[871 152]
#  [132  53]]

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 0.85
# Confusion Matrix:
# [[1002   21]
#  [ 160   25]]
